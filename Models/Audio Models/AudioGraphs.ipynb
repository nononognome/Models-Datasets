# %%
import tikzplotlib

import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
note = librosa.load("notes.mp3")

plt.plot(note[0][458000:525000:100], color="black")
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.xticks([])
plt.yticks([])
plt.ylim(-0.25, 0.25)
plt.title("C4 Sustained Note Waveform")

tikzplotlib.save("Note.tex")
# Out:
# /var/folders/mq/y1mzq23j39104lm0kgrz14180000gn/T/ipykernel_50706/4280030404.py:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   note = librosa.load("notes.mp3")
# [src/libmpg123/parse.c:skip_junk():1276] error: Giving up searching valid MPEG header after 65536 bytes of junk.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
